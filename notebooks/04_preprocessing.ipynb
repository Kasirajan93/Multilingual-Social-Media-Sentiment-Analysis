# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../data/processed/multilingual_sentiment.csv")

df.head()
# Out:
#                                                 text sentiment language
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...  Positive  English
# 1   Action king dialogue semma..... avanoda sindh...  Positive    Tamil
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...  Positive    Tamil
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...  Positive    Tamil
# 4                      Nfg greatest hits cd cracked   Negative  English

# %%
print(df.shape)
# Out:
# (30978, 3)

# %%
df["cleaned_text"] = df["text"]

# %%
df["cleaned_text"] = df["cleaned_text"].apply(
    lambda x: re.sub(r"http\S+|www\S+", "", str(x))
)

# %%
df[["text","cleaned_text"]].head()
# Out:
#                                                 text  \
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...
# 1   Action king dialogue semma..... avanoda sindh...
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...
# 4                      Nfg greatest hits cd cracked
#
#                                         cleaned_text
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...
# 1   Action king dialogue semma..... avanoda sindh...
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...
# 4                      Nfg greatest hits cd cracked

# %%
df[["text","cleaned_text"]].head()
# Out:
#                                                 text  \
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...
# 1   Action king dialogue semma..... avanoda sindh...
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...
# 4                      Nfg greatest hits cd cracked
#
#                                         cleaned_text
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...
# 1   Action king dialogue semma..... avanoda sindh...
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...
# 4                      Nfg greatest hits cd cracked

# %%
df["cleaned_text"] = df["cleaned_text"].str.replace(
    "#",
    "",
    regex=False
)

# %%
df["cleaned_text"] = df["cleaned_text"].apply(
    lambda x: re.sub(r"\d+", "", str(x))
)

# %%
df["cleaned_text"] = df["cleaned_text"].apply(
    lambda x: re.sub(
        r"[^\w\s\u0B80-\u0BFF\u0900-\u097F]",
        "",
        str(x)
    )
)

# %%
df["cleaned_text"] = df["cleaned_text"].str.lower()

# %%
df["cleaned_text"] = df["cleaned_text"].apply(
    lambda x: " ".join(x.split())
)

# %%
df = df[df["cleaned_text"].str.strip() != ""]

# %%
df[
    ["text","cleaned_text"]
].sample(10)
# Out:
#                                                     text  \
# 25780  hey taylor do you know of anywhere i can see t...
# 14551   Comments pakka ethana per. Vandhurkinga hit l...
# 10887                                     I sold my car
# 5590   home...still hasnt set in that i wont be going...
# 25654   Ennada mersal teaser likes kooda varla but th...
# 13032   All the best Ajith SIR - Pink was outstanding...
# 30640         Teaser ah vidama trailer ah vittutaga🤩🤩🤩🤩🤩
# 25991  How lovely is the weather  waiting for superna...
# 4211    vera level trailerda bigilukku ippaye sanga u...
# 20057            Sema sir inimel ipadi oru padam varadhu
#
#                                             cleaned_text
# 25780  hey taylor do you know of anywhere i can see t...
# 14551  comments pakka ethana per vandhurkinga hit lik...
# 10887                                      i sold my car
# 5590   homestill hasnt set in that i wont be going to...
# 25654  ennada mersal teaser likes kooda varla but tha...
# 13032  all the best ajith sir pink was outstanding so...
# 30640              teaser ah vidama trailer ah vittutaga
# 25991  how lovely is the weather waiting for supernat...
# 4211   vera level trailerda bigilukku ippaye sanga ut...
# 20057            sema sir inimel ipadi oru padam varadhu

# %%
df.to_csv(
    "../data/processed/multilingual_sentiment_cleaned.csv",
    index=False
)

print("Saved successfully")
# Out:
# Saved successfully

# %%
print(df.shape)

df[["text", "cleaned_text"]].head(10)
# Out:
# (30978, 4)
#                                                 text  \
# 0  Next date - Birmingham, The Rainbow, Sun 7th J...
# 1   Action king dialogue semma..... avanoda sindh...
# 2   Appedilaam nadekaathu, nadake kudaathu!! The ...
# 3   Looks like d Mixture of  Kaala+Kabali.....   ...
# 4                      Nfg greatest hits cd cracked
# 5  Sry ppls listenin to good music in a good mood...
# 6  TWitter!!! Finally joined  Follow me i'll foll...
# 7                 going to see UP in about an hour.
# 8                                 I love you SK Anna
# 9   69 vayasula avaroda stylea parrungada we love...
#
#                                         cleaned_text
# 0  next date birmingham the rainbow sun th june s...
# 1  action king dialogue semma avanoda sindhanayum...
# 2  appedilaam nadekaathu nadake kudaathu the bull...
# 3  looks like d mixture of kaalakabali sure antho...
# 4                       nfg greatest hits cd cracked
# 5  sry ppls listenin to good music in a good mood...
# 6    twitter finally joined follow me ill follow u d
# 7                   going to see up in about an hour
# 8                                 i love you sk anna
# 9  vayasula avaroda stylea parrungada we love u t...

# %%
print(df.shape)
# Out:
# (30978, 4)

# %% [markdown]
# Final cleaned dataset shape: (30878, 4)
# Columns:
# - text
# - sentiment
# - language
# - cleaned_text
